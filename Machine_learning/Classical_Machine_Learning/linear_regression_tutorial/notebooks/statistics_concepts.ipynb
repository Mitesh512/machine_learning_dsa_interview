# %%
# synthetic data generation for correlation 

import numpy as np
import pandas as pd

# Generate some data
np.random.seed(0)
X = np.random.normal(size=100)
Y = 2 * X + np.random.normal(size=100)

# Create a linear regression model
model = sm.OLS(Y, sm.add_constant(X)).fit()

# Check for correlation
print(model.params)  # Should show a strong positive correlation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9 Y = 2 * X + np.random.normal(size=100)
#      11 # Create a linear regression model
# ---> 12 model = sm.OLS(Y, sm.add_constant(X)).fit()
#      14 # Check for correlation
#      15 print(model.params)  # Should show a strong positive correlation
#
# NameError: name 'sm' is not defined
